# %% [markdown]
# # Web Scraping Job Vacancies

# %% [markdown]
# ## Introduction
#
# In this project, we'll build a web scraper to extract job listings from a popular job search platform. We'll extract job titles, companies, locations, job descriptions, and other relevant information.
#
# Here are the main steps we'll follow in this project:
#
# 1. Setup our development environment
# 2. Understand the basics of web scraping
# 3. Analyze the website structure of our job search platform
# 4. Write the Python code to extract job data from our job search platform
# 5. Save the data to a CSV file
# 6. Test our web scraper and refine our code as needed
#
# ## Prerequisites
#
# Before starting this project, you should have some basic knowledge of Python programming and HTML structure. In addition, you may want to use the following packages in your Python environment:
#
# - requests
# - BeautifulSoup
# - csv
# - datetime
#
# These packages should already be installed in Coursera's Jupyter Notebook environment, however if you'd like to install additional packages that are not included in this environment or are working off platform you can install additional packages using `!pip install packagename` within a notebook cell such as:
#
# - `!pip install requests`
# - `!pip install BeautifulSoup`

# %% [markdown]
# ## Step 1: Importing Required Libraries

# %%
# load packages
import requests
import pandas as pd
import json

# %%
# Since I could not find a job searching site allowing for web scraping with beautiful soup (due to anti-scraping mechanism) I decided to use API from the Swedish Employment Agency (Arbetsföremedlingen).

# Because of this I have used the package Json instead of beautiful soup.

# AMF API

# Making a request to the API
url = "https://links.api.jobtechdev.se/joblinks?"
query = {'q':"utvecklare", 'limit':100}
response = requests.get(url, params = query)

job_data = response.json()

# Check output
job_data
# Out:
# {'total': {'value': 933},
#  'hits': [{'id': '8ce3574c85086c70115d06fab3d6c052',
#    'headline': 'Utvecklare',
#    'brief': 'Om tjänstenVår kund är en av de absolut ledande aktörerna i sin bransch och kännetecknas av ett högt tekniskt kunnande och en harmonisk syn på balans mellan arbetsliv och fritid, här ges utrymme för en långsiktig och hållbar relation till arbetet. Projekten innebär utveckling av produktionsnära system till tillverkande företag och erbjuder stor variation, såsom nyutveckling eller vidareutveckling av redan implementerade system.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Procruitment AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'hRDj_PoV_sFU',
#      'municipality': 'Karlstad',
#      'region_concept_id': 'EVVp_h6U_GSZ',
#      'region': 'Värmlands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-22T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28644793'}]},
#   {'id': 'e4632705b2db5ae5366c5dfdc24d7a54',
#    'headline': 'Utvecklare',
#    'brief': 'Vår kund letar efter engagerade och erfarna utvecklare som är entusiastiska över att ansluta sig till vårt växande team. Som en framstående aktör inom betalningssektorn strävar vi kontinuerligt efter att förbättra och förnya våra produkter och tjänster för att uppfylla de evigt föränderliga kraven från våra kunder och användare.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Akkodis Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-02-05T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28491364'}]},
#   {'id': 'a264aecf225d3c795bd37ddaeda7260f',
#    'headline': 'Utvecklare',
#    'brief': 'Cancerfondens framgångar beror på vår förmåga att analysera, möta och samverka med omvärlden. Vi behöver beröra människors hjärtan, nå fler med viktig kunskap och få fler att bidra till svensk cancerforskning.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Cancerfonden - Riksfören Mot Cancer'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2023-11-15T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28249085'}]},
#   {'id': '76398f425b43ec961bd347edf04a9e4a',
#    'headline': 'Utvecklare C/C++',
#    'brief': 'Det har redan hunnit gå ett kvartal av 2024 och kanske känner du att i år är året det händer. Att det i år är dags för att ta nästa steg i arbetslivet.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Nexer AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-28T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28662726'}]},
#   {'id': '31b981dfa0e0547519578876ff77de66',
#    'headline': 'Citrix Utvecklare',
#    'brief': 'Vill du vara en del av en organisation som arbetar för att skydda både människor och samhällen? Är du en person med ett stort intresse, kunskap och erfarenhet inom Citrix?',
#    'occupation_group': {'label': 'Supporttekniker, IT',
#     'concept_id': 'hmaC_cfi_UKg'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'NXT Interim Göteborg AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-26T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28657201'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28652062'}]},
#   {'id': '1d996128dd6670283fc88547a7b78b3a',
#    'headline': 'Citrix utvecklare',
#    'brief': 'Vill du vara en del av en organisation som arbetar för att skydda både människor och samhällen? Är du en person med ett stor intresse, kunskap och erfarenhet inom Citrix?',
#    'occupation_group': {'label': 'Supporttekniker, IT',
#     'concept_id': 'hmaC_cfi_UKg'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'NXT Interim Stockholm AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28652062'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28657201'}]},
#   {'id': 'a9c138e6b578eb66c37a6682bb16f549',
#    'headline': 'Utvecklare Matlab/Simulink',
#    'brief': 'Nexer letar efter dig som har erfarenhet av arbete i Matlab eller Simulink och som arbetat inom automotive branschen. Här får du vara med på början av resan när vi bygger en konsultgrupp med fokus på Automotive och Elektromobility här i Göteborg.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Nexer AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28649419'}]},
#   {'id': 'd959200c5836468c6da260c94091a86c',
#    'headline': 'C#/React utvecklare',
#    'brief': 'Vi söker en fd yrkesverksam - men fortfarande aktiv - systemutvecklare som under flera år framöver vill jobba deltid med en större kommersiell produkt. Arbetet bedrivs i huvudsak på distans med vissa möten i Stockholm eller Oslo beroende på bostadsort.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Itancan Consulting AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-21T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28643392'}]},
#   {'id': '07763fa775a36be1fd510b43422dd301',
#    'headline': 'Fullstack utvecklare',
#    'brief': 'Vi söker en erfaren fullstack-utvecklare som kommer att vara en del av vårt dynamiska och kompetenta utvecklingsteam. Som utvecklare hos oss kommer du att arbeta med att utveckla och implementera mjukvarulösningar för våra kunders behov.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Alten Sverige AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28638543'},
#     {'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/fullstack-utvecklare/260427'}]},
#   {'id': '063da45b55677543197eb594b66ef578',
#    'headline': 'Fullstack utvecklare',
#    'brief': 'Vi söker en erfaren fullstack-utvecklare som kommer att vara en del av vårt dynamiska och kompetenta utvecklingsteam. Som utvecklare hos oss kommer du att arbeta med att utveckla och implementera mjukvarulösningar för våra kunders behov.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Alten'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/fullstack-utvecklare/260427'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28638543'}]},
#   {'id': 'a4afda4a9409b6bcfb64507936e23359',
#    'headline': 'Frontend- utvecklare',
#    'brief': 'Vill du koda e-handel, appar och webbtjänster?Vi söker en passionerad och erfaren Frontend- utvecklare för att förstärka vårt team vid utvecklingen av spännande och användarvänliga webbapplikationer. Som Frontend- utvecklare kommer du att vara ansvarig för att designa och implementera användargränssnitt för våra kunder & dina nya kollegor!Resultatet av ditt jobb kommer att användas av flera miljoner användare i Sverige!',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Iduna AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-19T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28632925'}]},
#   {'id': 'cdd960cebcfb842e2cb7f65eba43ac82',
#    'headline': 'Utvecklare (DevOps)',
#    'brief': 'Försvarsmaktens Telekommunikations- och informationssystemförband (FMTIS) söker en Utvecklare. Vi lever i en tid när stora krav ställs på Försvarsmaktens förmågetillväxt.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Försvarsmakten'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-16T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28625331'}]},
#   {'id': 'a32f648964192d78d1d9970c74cb57d4',
#    'headline': 'Fullstack utvecklare',
#    'brief': 'DirSys växer och är mitt i en spännande utvecklingsfas. Vi söker dig med erfarenhet av att arbeta med utveckling och utvecklingsmetoder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Dirsys AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-14T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28617146'}]},
#   {'id': '6214704c5db0e4d1a2b3b4146550cc55',
#    'headline': 'Mainframe utvecklare',
#    'brief': 'Om tjänsten:Du kommer att ansluta till den digitala delen av ett område som levererar stabila logistikflöden av reservdelar till globala destinationer inom fordonsindustrin. Tjänsten innebär applikationsutveckling, mainframe utveckling, samordna och koordinera leverans med arkitekter, produktägare och kollegor i produktteamet för att säkerställa i lösningar.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Xamera AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-14T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28616865'}]},
#   {'id': '3898d05567478b02b5269cb9dacfc118',
#    'headline': 'Utvecklare Inbyggdasystem',
#    'brief': 'EC Konsult AB är ett konsultbolag med passion för teknik. Vi har hängivna utvecklare av inbyggda system som ingår i olika team som gör produktutveckling.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Ec Konsult AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-13T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28598369'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28598389'}]},
#   {'id': '44dd1c990ee035f22148529d45a18f66',
#    'headline': 'Senior utvecklare',
#    'brief': 'Vill du jobba med teknik i framkant, samtidigt som du bidrar till samhällsnyttan? Hos oss får du intressanta arbetsuppgifter i samhällets hjärta, kombinerat med utvecklingsmöjligheter och balans mellan arbete och fritid.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Skatteverket'},
#    'workplace_addresses': [{'municipality_concept_id': 'QiGt_BLu_amP',
#      'municipality': 'Umeå',
#      'region_concept_id': 'g5Tt_CAV_zBd',
#      'region': 'Västerbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-12T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28610177'}]},
#   {'id': '7c839069aee72171eadeb64dcb74b936',
#    'headline': 'Utvecklare Inbyggdasystem',
#    'brief': 'EC Konsult AB är ett konsultbolag med passion för teknik. Vi har hängivna utvecklare av inbyggda system som ingår i olika team som gör produktutveckling.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Ec Konsult AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-10T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28598389'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28598369'}]},
#   {'id': 'cbd433e9a71ea179c383ca8b0093aef3',
#    'headline': 'Android utvecklare ',
#    'brief': 'Jobbeskrivning As developer in one of our teams you’ll have the opportunity to work with the latest technology in an exciting and global environment. We team up with Google and other big players to deliver world class android applications and services to support the clients vision to be the most desired and successful transport solution and infrastructure provider in the world.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Segula Technologies AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-06T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28590561'}]},
#   {'id': '5c609b07f9a88353ccb55c505ee65eac',
#    'headline': 'DevOps Utvecklare',
#    'brief': 'Vår kund växer snabbt och står inför en lång och spännande resa med aktuella samhällsnyttiga projekt. På denna resa spelar IT en väsentlig roll.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'NXT Interim Malmö AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'oYPt_yRA_Smm',
#      'municipality': 'Malmö',
#      'region_concept_id': 'CaRE_1nn_cSU',
#      'region': 'Skåne län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-06T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28589576'}]},
#   {'id': '2f181911d1ebe609c2a5b33381ebb7e1',
#    'headline': 'Sharepoint utvecklare',
#    'brief': 'Vår kund växer snabbt och står inför en lång och spännande resa med aktuella samhällsnyttiga projekt. På denna resa spelar IT en väsentlig roll.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'NXT Interim Göteborg AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'PVZL_BQT_XtL',
#      'municipality': 'Göteborg',
#      'region_concept_id': 'zdoY_6u5_Krt',
#      'region': 'Västra Götalands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-06T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28593145'}]},
#   {'id': '03051e530b34f9d21f39ca6d87a626a4',
#    'headline': 'Backend Utvecklare',
#    'brief': 'Vill du vara en del av ett kreativt och handelskraftigt team som arbetar med den senaste teknologin? Vi på Dialect i Skövde växer och söker nu en utvecklare!Information om vem vi sökerVi tror att du har en bakgrund som t. ex.  back-end utvecklare och är varm i kläderna när det kommer till programmeringens alla finesser.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Dialect IT Solutions AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-02-15T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28527290'}]},
#   {'id': '92eae74d5c69e7c8b40d53e01ef32427',
#    'headline': 'Erfaren utvecklare',
#    'brief': 'Vill du arbeta tillsammans med prestigelösa kollegor som värdesätter kunskapsdelning och att leverera hög kvalitet i tekniskt utmanande uppdrag? Går du i tankar om nya utmaningar under 2024?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-01-16T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28423514'}]},
#   {'id': '65c2d409729f6eb6bad0383d8c60fd31',
#    'headline': 'Senior utvecklare',
#    'brief': 'Vill du arbeta tillsammans med prestigelösa kollegor som värdesätter kunskapsdelning och att leverera hög kvalitet i roliga och tekniskt utmanande uppdrag? Går du i tankar om nya utmaningar under 2024?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-01-16T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28423124'}]},
#   {'id': '32336a699d131e36b3d516cec9c4639d',
#    'headline': 'Senior utvecklare',
#    'brief': 'Varmt välkommen att bli en del av ett härligt gäng i Helsingborg. Hos oss får du möjlighet att jobba i spännande projekt, jobba med den senaste tekniken (klyschigt men ändock sant) och fortsätta utvecklas tillsammans med dina kollegor.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Knowit AB (Publ)'},
#    'workplace_addresses': [],
#    'publication_date': '2024-01-12T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28410939'}]},
#   {'id': 'c6665a341c24a67606a2f74e05f0fa28',
#    'headline': 'Utvecklare ServiceNow',
#    'brief': 'Vi söker en erfaren och kunnig ServiceNow-utvecklare att ansluta sig till vårt team. Som ServiceNow-utvecklare kommer du att vara ansvarig för att designa, utveckla och implementera ServiceNow-lösningar för att möta affärsbehov ute hos en av våra kunder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sigma Technology IT INFRA AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214236'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214239'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214238'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214240'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214243'}]},
#   {'id': 'a7b3e1257a0a9f7bfe55748b633298dd',
#    'headline': 'Utvecklare ServiceNow',
#    'brief': 'Vi söker en erfaren och kunnig ServiceNow-utvecklare att ansluta sig till vårt team. Som ServiceNow-utvecklare kommer du att vara ansvarig för att designa, utveckla och implementera ServiceNow-lösningar för att möta affärsbehov ute hos en av våra kunder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sigma Technology IT INFRA AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214239'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214236'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214238'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214240'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214243'}]},
#   {'id': '65197c07e4cbdc04ca931bd48d9a18ff',
#    'headline': 'Utvecklare ServiceNow',
#    'brief': 'Vi söker en erfaren och kunnig ServiceNow-utvecklare att ansluta sig till vårt team. Som ServiceNow-utvecklare kommer du att vara ansvarig för att designa, utveckla och implementera ServiceNow-lösningar för att möta affärsbehov ute hos en av våra kunder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sigma Technology IT INFRA AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214238'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214236'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214239'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214240'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214243'}]},
#   {'id': 'e9946307bd4ce4505de501a3c59535c0',
#    'headline': 'Utvecklare ServiceNow',
#    'brief': 'Vi söker en erfaren och kunnig ServiceNow-utvecklare att ansluta sig till vårt team. Som ServiceNow-utvecklare kommer du att vara ansvarig för att designa, utveckla och implementera ServiceNow-lösningar för att möta affärsbehov ute hos en av våra kunder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sigma Technology IT INFRA AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214240'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214236'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214239'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214238'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214243'}]},
#   {'id': '23b8d05f310f3eef237a978ed1760277',
#    'headline': 'Utvecklare ServiceNow',
#    'brief': 'Vi söker en erfaren och kunnig ServiceNow-utvecklare att ansluta sig till vårt team. Som ServiceNow-utvecklare kommer du att vara ansvarig för att designa, utveckla och implementera ServiceNow-lösningar för att möta affärsbehov ute hos en av våra kunder.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sigma Technology IT INFRA AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214243'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214236'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214239'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214238'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28214240'}]},
#   {'id': '4da78c6a73e1c389a391b50a8a0a076e',
#    'headline': 'Business Intelligence Utvecklare',
#    'brief': 'Är du vår nya Business Intelligence Utvecklare?På Softhouse befinner vi oss i en viktig fas på vår tillväxtresa och nu är vi på jakt efter en Business Intelligence Utvecklare som vill ansluta till vårt kontor i Stockholm. Vi brinner för ny teknik och gillar att utvecklas, och utveckla, tillsammans.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28649211'}]},
#   {'id': '8acb600963fd5f045b5c4863b0911010',
#    'headline': 'Utvecklare inbyggda system',
#    'brief': 'Din roll hos Akkodis är att vara en nyckelspelare i utvecklingen och förvaltningen av inbyggda säkerhetskritiska realtidsoperativsystem. Tillsammans med ett dedikerat team kommer du att bidra till skapandet och underhållet av säkerhetskritisk mjukvara för avancerade militära produkter, inklusive befintliga och framtida stridsflygplan.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Akkodis Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28652614'}]},
#   {'id': '8135f0d4a0538574f48173a09d59ada5',
#    'headline': 'System- FPGA utvecklare',
#    'brief': 'Wireless P2P Technologies AB is a spin-off company founded 2014 in Falun, Sweden, based on mobile network innovations from leading Scandinavian technical universities. We develop proprietary wireless solutions for demanding customers.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Wireless P2P Technologies AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'N1wJ_Cuu_7Cs',
#      'municipality': 'Falun',
#      'region_concept_id': 'oDpK_oZ2_WYt',
#      'region': 'Dalarnas län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-21T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28642332'}]},
#   {'id': '8807fbe81fcef8663966a88a621ea56d',
#    'headline': 'Senior utvecklare Luleå',
#    'brief': 'Är du vår nästa kollega?På Softhouse Neava befinner vi oss i en viktig fas på vår tillväxtresa och nu är vi på jakt efter seniora utvecklare som vill ansluta till våra kontor i Luleå. Vi brinner för ny teknik och gillar att utvecklas, och utveckla, tillsammans.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'CXbY_gui_14v',
#      'municipality': 'Luleå',
#      'region_concept_id': '9hXe_F4g_eTG',
#      'region': 'Norrbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28638777'}]},
#   {'id': 'f2e9c54537a73ebb7bd5df25c4488d6b',
#    'headline': 'Utvecklare till Säkerhetsenheten',
#    'brief': 'Vill du vara med och bidra till att Eskilstuna blir säkrare och tryggare? Nu söker vi en utvecklare för tillsvidareanställning med fokus mot RSA, kontinuitetsplanering och säkerhetsskydd.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Eskilstuna kommun'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-19T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28634318'}]},
#   {'id': '5c75f63fb54e8a38718ef276c50a8079',
#    'headline': 'Utvecklare till Säkerhetsenheten',
#    'brief': 'Om arbetsplatsenVill du vara med och bidra till att Eskilstuna blir säkrare och tryggare? Nu söker vi en utvecklare för tillsvidareanställning med fokus mot RSA, kontinuitetsplanering och säkerhetsskydd.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Eskilstuna kommun, Kommunledningskontoret'},
#    'workplace_addresses': [{'municipality_concept_id': 'kMxr_NiX_YrU',
#      'municipality': 'Eskilstuna',
#      'region_concept_id': 's93u_BEb_sx2',
#      'region': 'Södermanlands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-19T00:00:00',
#    'source_links': [{'label': 'offentligajobb.se',
#      'url': 'https://www.offentligajobb.se/jobad/utvecklare-till-s%C3%A4kerhetsenheten_eskilstuna-s%C3%B6dermanlands-l%C3%A4n-sverige_007230f3-527d-4c4d-9d63-96d74c7c39da'}]},
#   {'id': 'd0759a90703987600cabbe1817176889',
#    'headline': 'Utvecklare inom testsystem',
#    'brief': 'FöretagsbeskrivningAFRY erbjuder tjänster inom teknik, design, digitalisering och rådgivning. Vi är hängivna experter inom industri, energi- och infrastruktur, som skapar värde för kommande generationer.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'AFRY AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'PVZL_BQT_XtL',
#      'municipality': 'Göteborg',
#      'region_concept_id': 'zdoY_6u5_Krt',
#      'region': 'Västra Götalands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-18T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28629933'}]},
#   {'id': '06b4946491a3ba9044a24d5e2c97531c',
#    'headline': 'Utvecklare till SaveLend',
#    'brief': 'SaveLend är ett fintech-bolag och vår huvudprodukt är en trading-plattform som gör det möjligt att investera i olika typer av krediter. Vi riktar oss både mot småsparare och stora institutionella investerare.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Awexia Executive Search AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-06T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28591393'}]},
#   {'id': '2dcc447863bf2f4c899d656589ab6be6',
#    'headline': 'Utvecklare inom Salesforce',
#    'brief': 'Är du intresserad av att arbeta på Sveriges Bästa Arbetsplats 2023? Som blivit utsedda till Karriärföretag flera år i rad och som av Gartner rankas till ett topp fem bolag inom Digital Transformation?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sopra Steria Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-02-22T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28547624'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28547574'}]},
#   {'id': '859f4282d9d3c887b0063366a242e132',
#    'headline': 'Utvecklare inom Salesforce',
#    'brief': 'Är du intresserad av att arbeta på Sveriges Bästa Arbetsplats 2023? Som blivit utsedda till Karriärföretag flera år i rad och som av Gartner rankas till ett topp fem bolag inom Digital Transformation?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sopra Steria Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-02-22T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28547574'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28547624'}]},
#   {'id': 'df44275ef77c2ae40c2ea5b9853b94f9',
#    'headline': 'Senior Embedded Utvecklare',
#    'brief': 'På\u202fPrevas tror vi på\u202fatt teknik gör världen bättre. Och för att lyckas göra den bättre, behöver vi personer som dig.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Prevas'},
#    'workplace_addresses': [{'municipality_concept_id': '8deT_FRF_2SP',
#      'municipality': 'Västerås',
#      'region_concept_id': 'G6DV_fKE_Viz',
#      'region': 'Västmanlands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-02-21T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/senior-embedded-utvecklare/255468'}]},
#   {'id': '770db201554d8b45d037b9d6c8f8c21a',
#    'headline': 'Senior Embedded Utvecklare',
#    'brief': 'På\u202fPrevas tror vi på\u202fatt teknik gör världen bättre. Och för att lyckas göra den bättre, behöver vi personer som dig.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Prevas AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-02-21T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28546582'}]},
#   {'id': '00f827d89547b9557a3ec2a3cdf357d3',
#    'headline': 'C++ utvecklare Luleå',
#    'brief': 'WeSkill AB söker nu ett antal utvecklare med erfarenhet av C++ och inbyggda system till ett långsiktigt uppdrag hos kund i Luleå. OmVi söker nu flertalet lösningsorienterade och genuint teknikintresserade utvecklare till uppdrag/projekt inom inbyggda system hos kund.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Weskill AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'CXbY_gui_14v',
#      'municipality': 'Luleå',
#      'region_concept_id': '9hXe_F4g_eTG',
#      'region': 'Norrbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-02-06T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28493355'}]},
#   {'id': '217e8b072466c7e92099be650fa67679',
#    'headline': 'Power Platform Utvecklare',
#    'brief': 'Brinner du för Microsofts plattformar och letar efter en spännande och givande karriärsmöjlighet? Om svaret är ja, då har vi den möjligheten för dig.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Meltlake AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-01-18T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28423249'}]},
#   {'id': '7fa74b3ef0e2998cd5835c9d449ef0c3',
#    'headline': 'Senior BI Utvecklare',
#    'brief': 'Vill du ta ditt konsultande till nästa nivå hos en av Sveriges bästa arbetsgivare? Vi vet vad du tänker.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Castra Group AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-01-18T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28432387'}]},
#   {'id': 'f2a0494cca4f0da50b909f491205c1d8',
#    'headline': 'Utvecklare inom ServiceNow',
#    'brief': 'Vill du arbeta på Sveriges bästa arbetsplats? Sopra Steria söker en erfaren ServiceNow-utvecklare för att stärka upp sitt.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sopra Steria Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-05T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305888'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305879'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305889'}]},
#   {'id': '5f017cae1780c9d21f9774389f4d33ee',
#    'headline': 'Utvecklare inom ServiceNow',
#    'brief': 'Vill du arbeta på Sveriges bästa arbetsplats? Sopra Steria söker en erfaren ServiceNow-utvecklare för att stärka upp sitt.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sopra Steria Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-05T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305879'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305888'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305889'}]},
#   {'id': '3a0da3461e52a23c6673aa04aa0ccb94',
#    'headline': 'Utvecklare inom ServiceNow',
#    'brief': 'Vill du arbeta på Sveriges bästa arbetsplats? Sopra Steria söker en erfaren ServiceNow-utvecklare för att stärka upp sitt.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Sopra Steria Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-05T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305889'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305888'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28305879'}]},
#   {'id': 'f13e71e161c049711084dc3baefeaa4c',
#    'headline': 'Senior utvecklare Småland',
#    'brief': 'Är du vår nästa kollega?På Softhouse befinner vi oss i en viktig fas på vår tillväxtresa och nu är vi på jakt efter seniora utvecklare som vill ansluta till våra kontor i Småland. Vi brinner för ny teknik och gillar att utvecklas, och utveckla, tillsammans.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28302793'}]},
#   {'id': 'f3db0151e47b790a3a67d75dcc69a826',
#    'headline': 'Junior utvecklare till Trafikförvaltningen',
#    'brief': 'Trafikförvaltningens verksamhet kräver mer och fler komplexa IT-lösningar för att utveckla kollektivtrafiken. Vill du vara med att göra vardagen bättre för Trafikförvaltningens 700 000 dagliga användare?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-28T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/junior-utvecklare-till-trafikforvaltningen/261703'}]},
#   {'id': '51590a9e60ad0d8cf1dfdbd639c4e5ed',
#    'headline': 'Junior utvecklare till Trafikförvaltningen',
#    'brief': 'Trafikförvaltningens verksamhet kräver mer och fler komplexa IT-lösningar för att utveckla kollektivtrafiken. Vill du vara med att göra vardagen bättre för Trafikförvaltningens 700 000 dagliga användare?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-28T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28664999'}]},
#   {'id': 'b0d39087e30b0f8cc5f3433366921483',
#    'headline': 'Utvecklare inom inbyggda system',
#    'brief': 'Vem är du? Vi söker en erfaren mjukvaruutvecklare som gillar embedded, C och C++.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Knightec AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'zBmE_n6s_MnQ',
#      'municipality': 'Örnsköldsvik',
#      'region_concept_id': 'NvUF_SP1_1zo',
#      'region': 'Västernorrlands län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-28T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28662859'}]},
#   {'id': 'f733a52612d17dcc4e9642e51337920c',
#    'headline': 'Utvecklare inom inbyggda system',
#    'brief': 'Vem är du? Vi söker en erfaren mjukvaruutvecklare som gillar embedded, C och C++.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Knightec AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'QiGt_BLu_amP',
#      'municipality': 'Umeå',
#      'region_concept_id': 'g5Tt_CAV_zBd',
#      'region': 'Västerbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-28T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28662923'}]},
#   {'id': '3dc428a8a2da88cd74fb684d8da8f2fa',
#    'headline': '.NET/C# utvecklare till Softhouse',
#    'brief': 'Är du vår nästa . NET/C# utvecklare?På Softhouse befinner vi oss i en viktig fas på vår tillväxtresa och nu är vi på jakt efter .',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'otaF_bQY_4ZD',
#      'municipality': 'Uppsala',
#      'region_concept_id': 'zBon_eET_fFU',
#      'region': 'Uppsala län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28649180'},
#     {'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28532627'}]},
#   {'id': 'fd5df9ccfc4bf7b6cb0fae355162a7ea',
#    'headline': 'Java utvecklare till Softhouse',
#    'brief': 'Är du vår nästa Java utvecklare?På Softhouse befinner vi oss i en viktig fas på vår tillväxtresa och nu är vi på jakt efter Java utvecklare till vårt kontor i Stockholm eller Uppsala. Vi brinner för ny teknik och gillar att utvecklas, och utveckla, tillsammans.',
# ...
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-25T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28649191'}]},
#   {'id': 'd3ee44a3ad07c96cf82454c03eb69fc2',
#    'headline': 'Erfarna utvecklare till nytt team',
#    'brief': 'Under vintern bytte One Group namn till Visionite. Vi har nytt namn är fortsatt samma IT-konsultbolag som alltid sätter individen i fokus.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Visionite Umeå AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-21T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28640320'}]},
#   {'id': 'c21615d1dcae3836d2b7abeb49f3c283',
#    'headline': 'Senior utvecklare till vårt Uppsalakontor!',
#    'brief': 'Är du redo att använda din expertis inom . NET för att göra en skillnad inom life science?Frontwalker Group, en etablerad aktör med över 35 år i IT-branschen, fortsätter sin resa mot innovation och teknisk expertis, särskilt inom life science och e-hälsa.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Frontwalker Group AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-21T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28640596'}]},
#   {'id': '03b46866be77fb512317ed156c445059',
#    'headline': 'C++ Utvecklare till Realtime Embedded',
#    'brief': 'Realtime Embedded AB (RTE) är specialister på innovation och produktutveckling. RTE utvecklar mjukvara och hårdvara för inbyggda system med fokus på industriell IoT och digitalisering.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Xlnt Search AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28637184'}]},
#   {'id': '493d8834eab862953d563600c72030eb',
#    'headline': 'Deploja söker en Frontend Utvecklare!',
#    'brief': 'Vi har nu ett behov hos en kund efter en Frontend Utvecklare och söker därför en ytterligare konsult och kollega med den rätta inställningen och som vill lära sig samt dela med sig av sina kunskaper. Med rätta inställningen vet vi att du skulle lyckas som konsult hos Deploja.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Deploja AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28639328'}]},
#   {'id': '7242f51f77b8d616a1d5ab3d50f4a309',
#    'headline': 'Utvecklare | Luleå | Experis ',
#    'brief': 'Vill du arbeta som konsult och få möjligheten att utforska olika branscher och projekt samtidigt som du bidrar med din expertis och erfarenhet inom Java-utveckling? Då väntar spännande möjligheter för dig hos oss, ansök idag och bli en del av vårt konsultteam!Vi söker dig som är en Java-utvecklare med minst 3 års erfarenhet inom området.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Experis AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'CXbY_gui_14v',
#      'municipality': 'Luleå',
#      'region_concept_id': '9hXe_F4g_eTG',
#      'region': 'Norrbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-20T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28638075'}]},
#   {'id': '0ae83075ffcdd41f22ebb982943e4bc5',
#    'headline': 'Backend utvecklare till SF Anytime!',
#    'brief': 'Trivs du i en miljö där det ekar av filmcitat och spänningen inför nästa storfilm? Vill du jobba i moderna miljöer med att skapa den bästa streamingupplevelsen?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-19T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/backend-utvecklare-med-intresse-for-film-och-streaming/242400'}]},
#   {'id': 'fb59804becfb3713988e307b1eaa06d6',
#    'headline': 'Business Intelligence utvecklare – Kiruna',
#    'brief': 'Modernera är ett modernt rekryterings- och bemanningsföretag. www.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Modernera AB'},
#    'workplace_addresses': [{'municipality_concept_id': 'biN6_UiL_Qob',
#      'municipality': 'Kiruna',
#      'region_concept_id': '9hXe_F4g_eTG',
#      'region': 'Norrbottens län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-19T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28635378'}]},
#   {'id': '5729135f10dd902dedca3a283d22ed06',
#    'headline': 'Senior utvecklare - inbyggda system',
#    'brief': 'Hej, Anna och Emil här! Vill du jobba med en blandning av konsultuppdrag och inhouse-projekt?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Avalon Innovation Technology AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-18T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28628192'}]},
#   {'id': 'f116b0e2d5f04707927d4b5799d6edb2',
#    'headline': 'C/ C++ utvecklare till försvarsindustrin!',
#    'brief': 'Ta chansen att få bli en del av försvarsindustrin. Vi söker dig som vill axla rollen som utvecklare med kunskap i C/C++.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work'},
#    'workplace_addresses': [{'municipality_concept_id': 'wgJm_upX_z5W',
#      'municipality': 'Karlskoga',
#      'region_concept_id': 'xTCk_nT5_Zjm',
#      'region': 'Örebro län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-03-14T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/c-c-utvecklare-till-forsvarsindustrin/230893'}]},
#   {'id': 'e5c4b8bb2a4328b4a480b91d3d91ecc9',
#    'headline': 'Senior Utvecklare C# / .NET',
#    'brief': 'FöretagsbeskrivningAFRY är en europeisk ledare inom ingenjörs-, design- och rådgivningstjänster med global räckvidd. Vi påskyndar omställningen mot ett hållbart samhälle.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'AFRY AB'},
#    'workplace_addresses': [],
#    'publication_date': '2024-03-13T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28612646'}]},
#   {'id': '006a5bb80199c995808e1afdd35d83af',
#    'headline': 'Utvecklare | Problemlösare | Hacker',
#    'brief': 'Vill du göra samhällsnytta och bidra till Sveriges oberoende i världen? FRA söker nu utvecklare/problemlösare/hackers som motiveras av att lära sig och utvecklas för arbete med\xa0myndighetens accessetablering inom avdelningen för cyberverksamhet.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'FRA'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-02-21T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/utvecklare-problemlosare-hacker/249221'},
#     {'label': 'ingenjorsguiden.se',
#      'url': 'https://ingenjorsguiden.se/jobb/fra/utvecklare-problemlosare-hacker'}]},
#   {'id': '662dab235ff4790cc4f2585212ac7eaf',
#    'headline': 'Frontend utvecklare till Tietoevry Banking',
#    'brief': 'JavaScript, React, HTML/CSS, ELQ, Azure DevOps med flera, är tekniker du får arbeta med hos Tietoevry Banking. I rollen kommer du tillsammans med ditt team att utveckla avancerade och skräddarsydda digitala lösningar.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2024-02-06T00:00:00',
#    'source_links': [{'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/frontend-utvecklare-till-tietoevry-banking/233377'}]},
#   {'id': '225b3a97eefbf0e96348b18cf3aebbae',
#    'headline': 'Backend utvecklare till SF Anytime!',
#    'brief': 'Trivs du i en miljö där det ekar av filmcitat och spänningen inför nästa storfilm? Vill du jobba i moderna miljöer med att skapa den bästa streamingupplevelsen?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Academic Work Sweden AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-15T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28338572'}]},
#   {'id': '4d0784c586f5c8d9bfb55f8a1e869019',
#    'headline': 'iOS utvecklare till B3 Skilled',
#    'brief': 'Vem är vi?B3 Skilled AB är resultatet av en kreativ fusion mellan B3 Third Base AB och B3 Nuway AB. Vår imponerande historia inom mångsidig mjukvaruutveckling har inte bara placerat oss som ett av Sveriges Gasellföretag enligt Dagens Industri, utan det har också präglat oss som en kraft att räkna med.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'B3 Consulting Group AB (publ)'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-07T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28314046'}]},
#   {'id': '032fa29b2f0cbef3c5b2d275709f1057',
#    'headline': 'Utvecklare Småland - öppen ansökan',
#    'brief': 'Är du utvecklare som letar efter din nästa utmaning? Eller student som vill lära känna oss bättre?',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Softhouse Nordic AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-12-04T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28302855'}]},
#   {'id': 'a29e6530917df933ddafc1491da28e84',
#    'headline': 'Utvecklare | Problemlösare | Hacker',
#    'brief': 'FRA söker nu utvecklare/problemlösare/hackers som motiveras av att lära sig och utvecklas21 november Vill du göra samhällsnytta och bidra till Sveriges oberoende i världen? FRA söker nu utvecklare/problemlösare/hackers som motiveras av att lära sig och utvecklas för arbete med\xa0myndighetens accessetablering inom avdelningen för cyberverksamhet.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'FRA'},
#    'workplace_addresses': [{'municipality_concept_id': 'AvNB_uwa_6n6',
#      'municipality': 'Stockholm',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'region': 'Stockholms län',
#      'country_concept_id': 'i46j_HmG_v64',
#      'country': 'Sverige'}],
#    'publication_date': '2023-11-21T00:00:00',
#    'source_links': [{'label': 'ingenjorsguiden.se',
#      'url': 'https://ingenjorsguiden.se/jobb/fra/utvecklare-problemlosare-hacker'},
#     {'label': 'ingenjorsjobb.se.xmlfeed',
#      'url': 'https://ingenjorsjobb.se/lediga-jobb/utvecklare-problemlosare-hacker/249221'}]},
#   {'id': 'c44c8f46a546b450cdc09bd4e11ad70a',
#    'headline': 'Spännande möjlighet som Java utvecklare',
#    'brief': 'Vi har nu flera behov hos ett flertal kunder efter Javautvecklare och söker därför fler kollegor med den rätta inställningen och som söker ett friare upplägg som Konsult! Våra konsulter får uppleva en oslagbar känsla av frihet!Här är du inte bara en anställd, utan också så nära en egenföretagare man kan komma.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'Deploja AB'},
#    'workplace_addresses': [],
#    'publication_date': '2023-11-09T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28229419'}]},
#   {'id': '7a8fd127ea9691bd6191c347001c91e6',
#    'headline': 'Microsoft 365/ Power Platform utvecklare',
#    'brief': 'Microsoft 365 och Power Platform utvecklare sökes till B3 CodeRight!Vår vision är att varje medarbetare hos oss ska känna sig så motiverad och nöjd med sitt arbete att de vaknar med ett leende på måndag morgon. B3 CodeRight är ett litet företag med en nära gemenskap, bestående av ca 35 dedikerade medarbetare som drar fördel av styrkan och samhörigheten inom hela B3-koncernen.',
#    'occupation_group': {'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'concept_id': 'DJh5_yyF_hEM'},
#    'occupation_field': {'label': 'Data/IT', 'concept_id': 'apaJ_2ja_LuF'},
#    'employer': {'name': 'B3 Consulting Group AB (publ)'},
#    'workplace_addresses': [],
#    'publication_date': '2023-10-26T00:00:00',
#    'source_links': [{'label': 'arbetsformedlingen.se',
#      'url': 'https://arbetsformedlingen.se/platsbanken/annonser/28185398'}]}]}

# %%
# Creating empty dataframe

job_df = pd.DataFrame()

# Loop and create dataframe

# response.status_code == 200 and

for item in job_data['hits']:
    
    Title = item['headline']
    Company = item['employer']['name']
    
    if item['workplace_addresses']:
        Location = item['workplace_addresses'][0]['municipality']
    else:
        Location = 'No location'
                
    Description = item['brief']
    Publication_date = item['publication_date'].split('T')[0]
    Source = item['source_links'][0]['url']
    
    job_df = job_df.append({
    'Title':Title,
    'Company': Company,
    'Location': Location,
    'Description': Description,
    'Publication date': Publication_date,
    'Source': Source
    
    }, ignore_index = True)

# %%
# Reorder columns
order = ['Company', 'Title', 'Description', 'Location', 'Publication date', 'Source']
job_df = job_df.reindex(columns = order)

# %%
# check dateframe
job_df
# Out:
#                                 Company  \
# 0                       Procruitment AB
# 1                     Akkodis Sweden AB
# 2   Cancerfonden - Riksfören Mot Cancer
# 3                              Nexer AB
# 4               NXT Interim Göteborg AB
# ..                                  ...
# 95        B3 Consulting Group AB (publ)
# 96                  Softhouse Nordic AB
# 97                                  FRA
# 98                           Deploja AB
# 99        B3 Consulting Group AB (publ)
#
#                                        Title  \
# 0                                 Utvecklare
# 1                                 Utvecklare
# 2                                 Utvecklare
# 3                           Utvecklare C/C++
# 4                          Citrix Utvecklare
# ..                                       ...
# 95            iOS utvecklare till B3 Skilled
# 96        Utvecklare Småland - öppen ansökan
# 97       Utvecklare | Problemlösare | Hacker
# 98   Spännande möjlighet som Java utvecklare
# 99  Microsoft 365/ Power Platform utvecklare
#
#                                           Description     Location  \
# 0   Om tjänstenVår kund är en av de absolut ledand...     Karlstad
# 1   Vår kund letar efter engagerade och erfarna ut...  No location
# 2   Cancerfondens framgångar beror på vår förmåga ...    Stockholm
# 3   Det har redan hunnit gå ett kvartal av 2024 oc...  No location
# 4   Vill du vara en del av en organisation som arb...  No location
# ..                                                ...          ...
# 95  Vem är vi?B3 Skilled AB är resultatet av en kr...  No location
# 96  Är du utvecklare som letar efter din nästa utm...  No location
# 97  FRA söker nu utvecklare/problemlösare/hackers ...    Stockholm
# 98  Vi har nu flera behov hos ett flertal kunder e...  No location
# 99  Microsoft 365 och Power Platform utvecklare sö...  No location
#
#    Publication date                                             Source
# 0        2024-03-22  https://arbetsformedlingen.se/platsbanken/anno...
# 1        2024-02-05  https://arbetsformedlingen.se/platsbanken/anno...
# 2        2023-11-15  https://arbetsformedlingen.se/platsbanken/anno...
# 3        2024-03-28  https://arbetsformedlingen.se/platsbanken/anno...
# 4        2024-03-26  https://arbetsformedlingen.se/platsbanken/anno...
# ..              ...                                                ...
# 95       2023-12-07  https://arbetsformedlingen.se/platsbanken/anno...
# 96       2023-12-04  https://arbetsformedlingen.se/platsbanken/anno...
# 97       2023-11-21  https://ingenjorsguiden.se/jobb/fra/utvecklare...
# 98       2023-11-09  https://arbetsformedlingen.se/platsbanken/anno...
# 99       2023-10-26  https://arbetsformedlingen.se/platsbanken/anno...
#
# [100 rows x 6 columns]

# %%
# Save as CSV
job_df.to_csv('job_listings.csv', index=False, encoding='utf-8')
